# %%
# import google.generativeai as genai

# genai.configure(api_key="AIzaSyDUzi1aauluPA859Ef5m73p2zzQ9FWdG1k")

# response = genai.embed_content(
#     model="models/embedding-001",
#     content="/home/harish/Desktop/chatbot/docs",
#     task_type="RETRIEVAL_DOCUMENT"
# )

# print(response['embedding'])




import google.generativeai as genai
import numpy as np
import pandas as pd

genai.configure(api_key="AIzaSyDUzi1aauluPA859Ef5m73p2zzQ9FWdG1k")

response = genai.embed_content(
    model="models/embedding-001",
    content="/home/harish/Desktop/chatbot/docs",
    task_type="RETRIEVAL_DOCUMENT"
)

newembedding = (response['embedding'])
print(newembedding)


## --- STEP 0: CREATE OUR VECTOR DATABASE (DO THIS ONCE) ---

# Your original document chunks
#documents = "/home/harish/Desktop/chatbot/docs"
# documents = [
#     "Gemini is a family of multimodal large language models developed by Google DeepMind.",
#     "Announced on December 6, 2023, Gemini is positioned as a competitor to OpenAI's GPT-4.",
#     "Gemini is trained on a diverse dataset of both text and images from a variety of sources.",
#     "The training process for Gemini is a two-stage process.",
#     "Google offers Gemini in multiple sizes: Ultra, Pro, and Nano."
# ]

# Create embeddings for each document chunk
#model = "models/embedding-001"
# df = pd.DataFrame(documents, columns=['text'])

# def embed_fn(text):
#     return genai.embed_content(model=model, content=text, task_type="RETRIEVAL_DOCUMENT")['embedding']

# df['embedding'] = df['text'].apply(embed_fn)
# print("Document embeddings created successfully.")
# print(df)


# ## --- NOW, LET'S ASK A QUESTION ---

# # The user's question
# user_question = "What is Gemini trained on?"

# # Step 1: Embed the question
# question_embedding = genai.embed_content(
#     model=model,
#     content=user_question,
#     task_type="RETRIEVAL_QUERY" # Use RETRIEVAL_QUERY for questions
# )['embedding']

# # Step 2: Find relevant documents using Cosine Similarity
# def find_best_passages(query_embedding, dataframe, top_k=2):
#     """Computes cosine similarity and finds the top_k most similar passages."""
#     dataframe['query_embedding'] = [query_embedding] * len(dataframe)

#     # Using numpy for efficient vector operations
#     def cosine_similarity(row):
#         return np.dot(row['embedding'], row['query_embedding']) / (np.linalg.norm(row['embedding']) * np.linalg.norm(row['query_embedding']))

#     dataframe['similarity'] = dataframe.apply(cosine_similarity, axis=1)
#     top_passages = dataframe.sort_values(by='similarity', ascending=False).head(top_k)
#     return top_passages['text'].tolist()

# # Get the top 2 most relevant passages
# relevant_passages = find_best_passages(question_embedding, df, top_k=2)
# context = "\n---\n".join(relevant_passages)

# print(f"\nFound relevant passages:\n{context}")


# # Step 3: Generate the answer using the context
# prompt = f"""
# Answer the following question based only on the provided context.

# Context:
# {context}

# Question:
# {user_question}
# """

# # Call the generative model
# generative_model = genai.GenerativeModel("gemini-1.5-flash")
# answer = generative_model.generate_content(prompt)

# print(f"\nFinal Answer:\n{answer.text}")
# Out:
# [0.058147974, -0.01282551, -0.0688197, -0.030888652, 0.06411584, 0.016787317, 0.029349655, -0.018699987, 0.0053883386, 0.054598298, -0.045662634, 0.030209178, -0.045356862, -0.00013890724, 0.007680438, -0.06682549, 0.033298172, 0.026121132, -0.0169032, -0.0056723254, 0.006014998, 0.01127588, -0.01389096, -0.0020132437, 0.05485264, -0.0139671825, -0.006260557, -0.07069242, -0.03645063, 0.009823754, -0.027548244, 0.043683972, -0.04379991, -0.0018472495, -0.014488113, -0.026559524, -0.017676912, 0.058293916, -0.004549255, -0.012775201, -0.006291043, -0.022323983, -0.04980464, 0.011585091, -0.02750897, -0.018212387, -0.02550229, 0.016338615, 0.024054855, -0.034214232, 0.016352171, 0.015894301, 0.07551597, -0.0063203434, -0.0034885677, -0.02845195, 0.028919388, 0.018500822, -0.022508798, 0.01918794, -0.0027011952, 0.0065746172, 0.01353979, 0.05008814, -0.039399955, -0.07060103, -0.017445045, 0.0035049687, 0.04979902, 0.008388581, 0.01270624, -0.016734488, 0.014113377, -0.038695768, -0.008
# ...

# %%
 import google.generativeai as genai

genai.configure(api_key="AIzaSyDUzi1aauluPA859Ef5m73p2zzQ9FWdG1k")

response = genai.embed_content(
    model="models/embedding-001",
    content="/home/harish/Desktop/chatbot/docs",
    task_type="RETRIEVAL_DOCUMENT"
)

#print(response['embedding'])
newambedding = response['embedding']
print(newambedding)
# Out:
# [0.058147974, -0.01282551, -0.0688197, -0.030888652, 0.06411584, 0.016787317, 0.029349655, -0.018699987, 0.0053883386, 0.054598298, -0.045662634, 0.030209178, -0.045356862, -0.00013890724, 0.007680438, -0.06682549, 0.033298172, 0.026121132, -0.0169032, -0.0056723254, 0.006014998, 0.01127588, -0.01389096, -0.0020132437, 0.05485264, -0.0139671825, -0.006260557, -0.07069242, -0.03645063, 0.009823754, -0.027548244, 0.043683972, -0.04379991, -0.0018472495, -0.014488113, -0.026559524, -0.017676912, 0.058293916, -0.004549255, -0.012775201, -0.006291043, -0.022323983, -0.04980464, 0.011585091, -0.02750897, -0.018212387, -0.02550229, 0.016338615, 0.024054855, -0.034214232, 0.016352171, 0.015894301, 0.07551597, -0.0063203434, -0.0034885677, -0.02845195, 0.028919388, 0.018500822, -0.022508798, 0.01918794, -0.0027011952, 0.0065746172, 0.01353979, 0.05008814, -0.039399955, -0.07060103, -0.017445045, 0.0035049687, 0.04979902, 0.008388581, 0.01270624, -0.016734488, 0.014113377, -0.038695768, -0.008
# ...
